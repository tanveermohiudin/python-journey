# %% [markdown]
# <a href="https://colab.research.google.com/github/tanveermohiudin/python-journey/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x=[5,6,4,5,6,7,8,9]
y=[5,6,4,78,5,4,6,8]
plt.plot(x,y)
plt.title("Graph")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')
